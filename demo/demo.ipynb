# %%
import pickle
import pandas as pd


# Read pickle file
# data = pd.read_pickle('tools/data/aicitychallenge/Rightside_window_user_id_24491_NoAudio_0.24491.423.450.pkl')
# data = pd.read_pickle('tools/data/aicitychallenge/ntu60_xsub_train.pkl')
"""
Draft
new_picklefile = 'tools/data/aicitychallenge/new_custom_dataset_val.pkl'
picklefile = pd.read_pickle('tools/data/aicitychallenge/custom_dataset_val.pkl')
with open(new_picklefile, 'ab') as output:
    for key, value in picklefile.items():
        print(value)
        pickle.dump(value, new_picklefile)
"""

picklefile = pd.read_pickle('../data/ava/annotations/ava_dense_proposals_train.FAIR.recall_93.9.pkl')        
picklefile
# Out:
# {'-5KQ66BBWC4,0902': array([[0.003   , 0.125   , 0.119   , 0.837   , 0.742486],
#         [0.626   , 0.153   , 0.797   , 0.838   , 0.987177],
#         [0.326   , 0.185   , 0.47    , 0.887   , 0.996382],
#         [0.508   , 0.117   , 0.648   , 0.777   , 0.903317],
#         [0.222   , 0.031   , 0.362   , 0.529   , 0.983264],
#         [0.108   , 0.143   , 0.283   , 0.805   , 0.547549],
#         [0.773   , 0.143   , 0.862   , 0.351   , 0.82769 ],
#         [0.706   , 0.105   , 0.787   , 0.31    , 0.108642],
#         [0.805   , 0.289   , 0.997   , 0.991   , 0.983301],
#         [0.852   , 0.175   , 0.929   , 0.335   , 0.178122]]),
#  '-5KQ66BBWC4,0903': array([[0.516   , 0.134   , 0.659   , 0.788   , 0.995238],
#         [0.628   , 0.163   , 0.781   , 0.84    , 0.996272],
#         [0.326   , 0.172   , 0.489   , 0.895   , 0.999214],
#         [0.145   , 0.161   , 0.301   , 0.831   , 0.9853  ],
#         [0.876   , 0.157   , 0.993   , 0.443   , 0.871956],
# ...

# %%
from mmaction.apis import init_recognizer, inference_recognizer

# %%
config_file = '../configs/recognition/tsn/tsn_r50_video_inference_1x1x3_100e_kinetics400_rgb.py'
# download the checkpoint from model zoo and put it in `checkpoints/`
checkpoint_file = '../checkpoints/tsn_r50_1x1x3_100e_kinetics400_rgb_20200614-e508be42.pth'

# %%
# build the model from a config file and a checkpoint file
model = init_recognizer(config_file, checkpoint_file, device='cpu')

# %%
# test a single video and show the result:
video = 'demo.mp4'
label = '../tools/data/kinetics/label_map_k400.txt'
results = inference_recognizer(model, video)

labels = open(label).readlines()
labels = [x.strip() for x in labels]
results = [(labels[k[0]], k[1]) for k in results]

# %%
# show the results
for result in results:
    print(f'{result[0]}: ', result[1])
# Out:
# arm wrestling:  29.61644
# rock scissors paper:  10.754839
# shaking hands:  9.9084
# clapping:  9.189912
# massaging feet:  8.305307
